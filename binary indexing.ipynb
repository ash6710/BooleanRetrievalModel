# %%
import nltk
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import os

file_location = os.path.join('InformationRetrieval', '*.txt')
print(file_location)
# Out:
# InformationRetrieval\*.txt

# %%
import glob
filenames = glob.glob(file_location)
print(filenames)
# Out:
# ['InformationRetrieval\\doc1.txt', 'InformationRetrieval\\doc10.txt', 'InformationRetrieval\\doc11.txt', 'InformationRetrieval\\doc12.txt', 'InformationRetrieval\\doc13.txt', 'InformationRetrieval\\doc14.txt', 'InformationRetrieval\\doc15.txt', 'InformationRetrieval\\doc16.txt', 'InformationRetrieval\\doc17.txt', 'InformationRetrieval\\doc18.txt', 'InformationRetrieval\\doc19.txt', 'InformationRetrieval\\doc2.txt', 'InformationRetrieval\\doc20.txt', 'InformationRetrieval\\doc21.txt', 'InformationRetrieval\\doc22.txt', 'InformationRetrieval\\doc23.txt', 'InformationRetrieval\\doc24.txt', 'InformationRetrieval\\doc25.txt', 'InformationRetrieval\\doc26.txt', 'InformationRetrieval\\doc27.txt', 'InformationRetrieval\\doc28.txt', 'InformationRetrieval\\doc29.txt', 'InformationRetrieval\\doc3.txt', 'InformationRetrieval\\doc30.txt', 'InformationRetrieval\\doc31.txt', 'InformationRetrieval\\doc32.txt', 'InformationRetrieval\\doc33.txt', 'InformationRetrieval\\doc34.txt', 'InformationRetrieval\\doc35.txt', 'InformationRetrieval\\doc36.txt', 'InformationRetrieval\\doc37.txt', 'InformationRetrieval\\doc38.txt', 'InformationRetrieval\\doc39.txt', 'InformationRetrieval\\doc4.txt', 'InformationRetrieval\\doc40.txt', 'InformationRetrieval\\doc5.txt', 'InformationRetrieval\\doc6.txt', 'InformationRetrieval\\doc7.txt', 'InformationRetrieval\\doc8.txt', 'InformationRetrieval\\doc9.txt']

# %%
corpusfin=[]
for f in filenames:
    file = open(f,"r",encoding='utf-8' ,errors='ignore')
    line = file.read().replace("\n", " ")
    corpusfin.append(line)
    file.close()

# %%
print(len(corpusfin))
# Out:
# 40

# %%
from nltk.tokenize import RegexpTokenizer
corpus_words = []
tokenizer = RegexpTokenizer(r'\w+')
# Tokenize a paragraph into sentences and each sentence in to
# words
for c in corpusfin:
    word_tokens = tokenizer.tokenize(c)
    corpus_words.append(word_tokens)

len(corpus_words)
# Out:
# 40

# %%
print(corpus_words)
# Out:
# [['The', 'Boy', 'Who', 'Lived', 'Mr', 'and', 'Mrs', 'Dursley', 'of', 'number', 'four', 'Privet', 'Drive', 'were', 'proud', 'to', 'say', 'that', 'they', 'were', 'perfectly', 'normal', 'thank', 'you', 'very', 'much', 'They', 'were', 'the', 'last', 'people', 'you', 'd', 'expect', 'to', 'be', 'involved', 'in', 'anything', 'strange', 'or', 'mysterious', 'because', 'they', 'just', 'didn', 't', 'hold', 'with', 'such', 'nonsense', 'Mr', 'Dursley', 'was', 'the', 'director', 'of', 'a', 'firm', 'called', 'Grunnings', 'which', 'made', 'drills', 'He', 'was', 'a', 'big', 'beefy', 'man', 'with', 'hardly', 'any', 'neck', 'although', 'he', 'did', 'have', 'a', 'very', 'large', 'moustache', 'Mrs', 'Dursley', 'was', 'thin', 'and', 'blonde', 'and', 'had', 'nearly', 'twice', 'the', 'usual', 'amount', 'of', 'neck', 'which', 'came', 'in', 'very', 'useful', 'as', 'she', 'spent', 'so', 'much', 'of', 'her', 'time', 'craning', 'over', 'garden', 'fences', 'spying', 'on', 'the', 'neighbours', 'The', 'Dursleys', 'had', 'a', 'small', 'son', 'called', 'Dudley', 'and', 'in', 'their', 'opinion', 'there', 'was', 'no', 'finer', 'boy', 'anywhere', 'The', 'Dursleys', 'had', 'everything', 'they', 'wanted', 'but', 'they', 'also', 'had', 'a', 'secret', 'and', 'their', 'greatest', 'fear', 'was', 'that', 'somebody', 'would', 'discover', 'it', 'They', 'didn', 't', 'think', 'they', 'could', 'bear', 'it', 'if', 'anyone', 'found', 'out', 'about', 'the', 'Potters', 'Mrs', 'Potter', 'was', 'Mrs', 'Dursley', 's', 'sister', 'but', 'they', 'hadn', 't', 'met', 'for', 'several', 'years', 'in', 'fact', 'Mrs', 'Dursley', 'pretended', 'she', 'didn', 't', 'have', 'a', 'sister', 'because', 'her', 'sister', 'and', 'her', 'good', 'for', 'nothing', 'husband', 'were', 'as', 'unDursleyish', 'as', 'it', 'was', 'possible', 'to', 'be', 'The', 'Dursleys', 'shuddered', 'to', 'think', 'what', 'the', 'neighbours', 'would', 'say', 'if', 'the', 'Potters', 'arrived', 'in', 'the', 'street', 'The', 'Dursleys', 'knew', 'that', 'the', 'Potters', 'had', 'a', 'small', 'son', 'too', 'but', 'they', 'had', 'never', 'even', 'seen', 'him', 'This', 'boy', 'was', 'another', 'good', 'reason', 'for', 'keeping', 'the', 'Potters', 'away', 'they', 'didn', 't', 'want', 'Dudley', 'mixing', 'with', 'a', 'child', 'like', 'that', 'When', 'Mr', 'and', 'Mrs', 'Dursley', 'woke', 'up', 'on', 'the', 'dull', 'grey', 'Tuesday', 'our', 'story', 'starts', 'there', 'was', 'nothing', 'about', 'the', 'cloudy', 'sky', 'outside', 'to', 'suggest', 'that', 'strange', 'and', 'mysterious', 'things', 'would', 'soon', 'be', 'happening', 'all', 'over', 'the', 'country', 'Mr', 'Dursley', 'hummed', 'as', 'he', 'picked', 'out', 'his', 'most', 'boring', 'tie', 'for', 'work', 'and', 'Mrs', 'Dursley', 'gossiped', 'away', 'happily', 'as', 'she', 'wrestled', 'a', 'screaming', 'Dudley', 'into', 'his', 'high', 'chair', 'None', 'of', 'them', 'noticed', 'a', 'large', 'tawny', 'owl', 'flutter', 'past', 'the', 'window', 'At', 'half', 'past', 'eight', 'Mr', 'Dursley', 'picked', 'up', 'his', 'briefcase', 'pecked', 'Mrs', 'Dursley', 'on', 'the', 'cheek', 'and', 'tried', 'to', 'kiss', 'Dudley', 'goodbye', 'but', 'missed', 'because', 'Dudley', 'was', 'now', 'having', 'a', 'tantrum', 'and', 'throwing', 'his', 'cereal', 'at', 'the', 'walls', 'Little', 'tyke', 'chortled', 'Mr', 'Dursley', 'as', 'he', 'left', 'the', 'house', 'He', 'got', 'into', 'his', 'car', 'and', 'backed', 'out', 'of', 'number', 'four', 's', 'drive', 'It', 'was', 'on', 'the', 'corner', 'of', 'the', 'street', 'that', 'he', 'noticed', 'the', 'first', 'sign', 'of', 'something', 'peculiar', 'a', 'cat', 'reading', 'a', 'map', 'For', 'a', 'second', 'Mr', 'Dursley', 'didn', 't', 'realise', 'what', 'he', 'had', 'seen', 'then', 'he', 'jerked', 'his', 'head', 'around', 'to', 'look', 'again', 'There', 'was', 'a', 'tabby', 'cat', 'standing', 'on', 'the', 'corner', 'of', 'Privet', 'Drive', 'but', 'there', 'wasn', 't', 'a', 'map', 'in', 'sight', 'What', 'could', 'he', 'have', 'been', 'thinking', 'of', 'It', 'm ...

# %%
corpuslower_words = []
tokenizer = RegexpTokenizer(r'\w+')
# Tokenize a paragraph into sentences and each sentence in to
# words

for corpus_word in corpus_words:
    word_tokens1 = set([ x.lower() for x in corpus_word])
    corpuslower_words.append(word_tokens1)

len(corpuslower_words)
# Out:
# 40

# %%
print(corpuslower_words)
# Out:
# [{'say', 'at', 'did', 'time', 'people', 'overhead', 'things', 'corner', 'moved', 'want', 'country', 'noticing', 'kiss', 'first', 'wanted', 'back', 'on', 'director', 'soon', 'amount', 'must', 'of', 'cloudy', 'his', 'swooping', 'yes', 'happily', 'number', 'what', 'undursleyish', 'tried', 'reading', 'sat', 'mr', 'found', 'four', 'it', 'second', 'somebody', 'nothing', 'left', 'whispering', 'later', 'potter', 'excitedly', 'little', 'came', 'together', 'nerve', 'probably', 'stared', 'see', 'jam', 'steering', 'just', 'head', 'secret', 'shuddered', 'thank', 'sister', 'sky', 'story', 'around', 'if', 'however', 'shake', 'there', 'wasn', 'normal', 'gazed', 'now', 'standing', 'struck', 'chortled', 'traffic', 'good', 'drills', 'high', 'several', 'eyes', 'silly', 'realise', 'collecting', 'twice', 'down', 'because', 'throwing', 'always', 'pointed', 'dudley', 'they', 'finer', 'drive', 'maps', 'ninth', 'her', 'owls', 'car', 'over', 'anywhere', 'morning', 'jerked', 'this', 'trick', 'dull', 'met', 'half', 'himself', 'goodbye', 'have', 'much', 'small', 'cheek', 'towards', 'greatest', 'seemed', 'grey', 'briefcase', 'past', 'none', 'privet', 'missed', 'about', 'firm', 'by', 'hadn', 'daylight', 'in', 'cereal', 'even', 'made', 'might', 'proud', 'lot', 'man', 'day', 'an', 'fact', 'map', 'been', 'mind', 'drummed', 'sign', 'years', 'useful', 'green', 'open', 'were', 'blinked', 'would', 'and', 'edge', 'concentrate', 'having', 'outside', 'no', 'window', 'although', 'signs', 'put', 'fashion', 'read', 'something', 'up', 'flutter', 'or', 'neighbours', 'couple', 'pretended', 'think', 'thin', 'hoping', 'floor', 'woke', 'free', 'as', 'then', 'child', 'strangely', 't', 'large', 'spying', 'fences', 'work', 'tawny', 'possible', 'lived', 'weren', 'tabby', 'noticed', 'was', 'bear', 'cats', 'after', 'owl', 'funny', 'garden', 'different', 'everything', 'harder', 'mouthed', 'involved', 'chair', 'pecked', 'watched', 'anything', 'backed', 'enraged', 'emerald', 'too', 'street', 'night', 'another', 'very', 'd', 'fear', 'cloak', 'driven', 'their', 'tie', 'peculiar', 'boring', 'else', 'these', 'boy', 'except', 'yelled', 'dressed', 'discover', 'for', 'the', 'that', 'nearly', 'gossiped', 'husband', 'help', 'dursley', 'cloaks', 'get', 'into', 'park', 'tyke', 'broad', 'supposed', 'said', 'wrestled', 'again', 'spent', 'clothes', 'hummed', 'picked', 'sped', 'who', 'light', 's', 'also', 'starts', 'new', 'than', 'close', 'when', 'him', 'away', 'last', 'obviously', 'huddle', 'she', 'you', 'expect', 'saw', 'screaming', 'didn', 'seen', 'knew', 'weirdos', 'anyone', 'got', 'nonsense', 'grunnings', 'moustache', 'reason', 'arrived', 'though', 'five', 'he', 'eight', 'keeping', 'to', 'older', 'sight', 'order', 'dursleys', 'son', 'out', 'like', 'beefy', 'road', 'could', 'why', 'mysterious', 'house', 'any', 'our', 'few', 'usual', 'mixing', 'drove', 'potters', 'wearing', 'ups', 'looking', 'office', 'a', 'town', 'some', 'quite', 'hold', 'be', 'which', 'but', 'thinking', 'gave', 'fell', 'with', 'young', 'had', 'hardly', 'suggest', 'them', 'look', 'such', 'stunt', 'never', 'all', 'craning', 'stupid', 'wheel', 'opinion', 'so', 'strange', 'minutes', 'called', 'happening', 'couldn', 'perfectly', 'blonde', 'tuesday', 'big', 'tantrum', 'most', 'mrs', 'walls', 'mirror', 'cat', 'neck', 'fingers', 'thought'}, {'ever', 'doing', 'say', 'piers', 'at', 'telling', 'fast', 'ask', 'did', 'time', 'people', 'slid', 'sure', 'worst', 'food', 'flash', 'bitten', 'lay', 'since', 'voice', 'watch', 'here', 'word', 'go', 'cupboard', 'back', 'safely', 'on', 'snake', 'asleep', 'strained', 'walked', 'really', 'uncoiling', 'horror', 'director', 'must', 'of', 'pain', 'his', 'violet', 'coat', 'nodded', 'anyway', 'take', 'done', 'what', 'tried', 'questions', 'sneaking', 'sat', 'leapt', 'mr', 'shock', 'bald', 'it', 'punching', 'next', 'second', 'specimen', 'later', 'being', 'little', 'came', 'waddling', 'before', 'vanish', 'parents', 'see', 'enough', 'until', 'head', 'shaken', 'almost', 'sworn', 'concrete', 'younger', 'talking',  ...

# %%
def positional_index(tokens):
    d = defaultdict(lambda:[])
    for docID, sub_l in enumerate(tokens):
        for t in set(sub_l):
            d[t].append([docID] + [ind for ind, ele in enumerate(sub_l) if ele == t])
    return d

# %%
index=  positional_index(corpuslower_words)
index["pretend"]
# Out:
# [[35, 263], [38, 277]]

# %%
index["hagrid"]
# Out:
# [[7, 293],
#  [8, 316],
#  [9, 286],
#  [10, 328],
#  [12, 315],
#  [13, 288],
#  [14, 322],
#  [15, 299],
#  [16, 300],
#  [17, 350],
#  [18, 296],
#  [19, 307],
#  [20, 293],
#  [23, 277],
#  [25, 322],
#  [26, 348],
#  [28, 558],
#  [30, 371],
#  [31, 355],
#  [33, 272],
#  [34, 337],
#  [35, 281],
#  [36, 301]]

# %%
def biwords(corpus_words):
    bilist=[]
    types= nltk.pos_tag(corpus_words) #saving the positional tags of the list of strings passed
    x= len(types) 
    for ttuple in types:
        #print(ttuple[1])
        bilist.append(ttuple[1]) # adding only the tags to other list
    return bilist

# %%
tip= biwords(corpus_words[1])
print(tip)
# Out:
# ['DT', 'NN', 'VBD', 'PRP$', 'NN', 'NNS', 'NNP', 'NNP', 'CC', 'NNP', 'RB', 'VBD', 'PRP$', 'NNS', 'TO', 'DT', 'NN', 'PRP', 'VBD', 'NNP', 'DT', 'NN', 'WDT', 'VBD', 'RB', 'RB', 'PRP', 'VBP', 'IN', 'PDT', 'DT', 'NN', 'PRP', 'VBP', 'NNP', 'VBD', 'IN', 'DT', 'NN', 'IN', 'PRP', 'VBZ', 'JJ', 'JJ', 'DT', 'NN', 'MD', 'VB', 'PRP', 'PRP', 'MD', 'VB', 'RB', 'VBG', 'DT', 'NN', 'VBD', 'RB', 'WRB', 'VB', 'PRP', 'VB', 'IN', 'RB', 'NNP', 'VBD', 'DT', 'NN', 'VBD', 'PRP$', 'NN', 'IN', 'DT', 'JJ', 'NN', 'IN', 'TO', 'DT', 'NN', 'NNP', 'VBD', 'IN', 'PRP', 'NNP', 'NNP', 'NNP', 'NNP', 'PRP', 'RB', 'EX', 'DT', 'NN', 'NN', 'VBD', 'PRP$', 'NN', 'IN', 'DT', 'NN', 'RB', 'CC', 'NNP', 'VBP', 'IN', 'DT', 'NN', 'VBD', 'VBN', 'IN', 'DT', 'NN', 'NNP', 'PRP', 'VBP', 'RB', 'PRP', 'VBP', 'RB', 'VBN', 'TO', 'NNP', 'IN', 'DT', 'NN', 'VBD', 'PRP$', 'NN', 'DT', 'NN', 'NN', 'IN', 'NNP', 'VBD', 'DT', 'IN', 'PRP', 'VBP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'WP', 'NNP', 'NNP', 'NNP', 'NNP', 'VBD', 'VBG', 'NNS', 'PRP', 'RB', 'RB', 'IN', 'PRP', 'MD', 'VB', 'IN', 'DT', 'NN', 'PRP', 'PRP', 'VBD', 'VBG', 'NNP', 'IN', 'DT', 'NN', 'NNP', 'IN', 'NN', 'NNP', 'VBD', 'RB', 'IN', 'DT', 'JJ', 'NN', 'WP', 'VBD', 'JJ', 'VBD', 'RB', 'JJ', 'DT', 'NN', 'VBD', 'WRB', 'PRP', 'VBD', 'CD', 'JJ', 'NNPS', 'CC', 'NNP', 'VBD', 'VBG', 'RB', 'RB', 'RB', 'TO', 'DT', 'NN', 'DT', 'JJ', 'PRP', 'VBD', 'VBN', 'RP', 'IN', 'NN', 'IN', 'NN', 'NNP', 'VBD', 'RP', 'CC', 'VBD', 'DT', 'NN', 'NN', 'IN', 'DT', 'NN', 'NN', 'VBD', 'NN', 'VBD', 'VBN', 'DT', 'JJ', 'NN', 'VBD', 'VBG', 'PRP', 'RB', 'VBG', 'RP', 'IN', 'TO', 'DT', 'NN', 'NNS', 'IN', 'DT', 'NN', 'NN', 'VBD', 'CC', 'VBD', 'VBG', 'IN', 'DT', 'NNS', 'IN', 'DT', 'NN', 'VBD', 'RB', 'IN', 'PRP', 'NNP', 'MD', 'VB', 'VBN', 'DT', 'JJ', 'NN', 'NN', 'VBD', 'NNP', 'RB', 'PRP', 'VBP', 'NNP', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', 'NN', 'VBD', 'IN', 'NN', 'CC', 'DT', 'NN', 'PRP', 'VBD', 'VBG', 'WRB', 'VBD', 'DT', 'NN', 'VBP', 'DT', 'NN', 'NN', 'PRP', 'VBD', 'NNP', 'NNP', 'DT', 'NN', 'IN', 'JJ', 'JJ', 'NN', 'IN', 'PRP', 'VBD', 'RB', 'CC', 'RB', 'RB', 'NNS', 'CC', 'NNP', 'MD', 'RB', 'VB', 'NNP', 'RB', 'IN', 'NNP', 'VBD', 'VBN', 'DT', 'NN', 'NN', 'NN', 'VBN', 'NN', 'IN', 'JJ', 'RB', 'IN', 'PRP$', 'NNS', 'IN', 'PRP', 'VBD', 'CC', 'IN', 'DT', 'NN', 'PRP', 'VBD', 'DT', 'RB', 'IN', 'NNP', 'NNP', 'NN', 'NN', 'NNP', 'VBD', 'VBG', 'PRP', 'WRB', 'PRP', 'VBD', 'RB', 'VBN', 'RP', 'PRP$', 'NN', 'IN', 'NNP', 'VBD', 'VBG', 'PRP', 'VBD', 'VBN', 'TO', 'VB', 'PRP', 'TO', 'NN', 'CC', 'JJS', 'IN', 'DT', 'IN', 'NNP', 'IN', 'JJS', 'VBD', 'NNP', 'VBG', 'RB', 'RB', 'TO', 'VB', 'NNP', 'VBD', 'VBG', 'TO', 'PRP', 'VB', 'IN', 'PRP', 'VBP', 'NNP', 'NNP', 'VBD', 'IN', 'NNP', 'VBD', 'RB', 'IN', 'IN', 'DT', 'NN', 'IN', 'VBG', 'IN', 'NNP', 'PRP', 'VBD', 'RB', 'JJ', 'PRP', 'MD', 'RB', 'VB', 'PRP', 'VBD', 'TO', 'VB', 'NNP', 'RB', 'VBZ', 'DT', 'NNS', 'IN', 'PRP', 'VBD', 'IN', 'DT', 'NN', 'CC', 'NNP', 'NNP', 'VBD', 'TO', 'VB', 'CC', 'VB', 'PRP', 'DT', 'JJ', 'NN', 'NNP', 'NN', 'IN', 'PRP$', 'JJ', 'NN', 'RB', 'RBR', 'VBG', 'PRP', 'VBD', 'DT', 'NN', 'PRP', 'VBZ', 'NN', 'VB', 'WP', 'NN', 'PRP', 'VBD', 'CC', 'PRP', 'VBD', 'RB', 'VB', 'JJ', 'DT', 'NNP', 'VBD', 'JJ', 'RB', 'IN', 'PRP', 'VBD', 'PRP', 'VBZ', 'NN', 'NN', 'VBG', 'TO', 'DT', 'NN', 'IN', 'DT', 'NN', 'PRP', 'VBZ', 'VBN', 'IN', 'DT', 'NNP', 'RB', 'CD', 'NNS', 'RB', 'JJ', 'NNS', 'RB', 'RB', 'IN', 'PRP', 'MD', 'VB', 'RB', 'IN', 'PRP', 'VBZ', 'VBN', 'DT', 'NN', 'CC', 'PRP$', 'NNS', 'VBD', 'VBN', 'IN', 'DT', 'NN', 'NN', 'PRP', 'VBZ', 'JJ', 'VB', 'VBG', 'IN', 'DT', 'NN', 'WRB', 'PRP$', 'NNS', 'VBD', 'VBN', 'RB', 'WRB', 'PRP', 'VBD', 'PRP$', 'NN', 'IN', 'JJ', 'NNS', 'IN', 'PRP$', 'NN', 'PRP', 'VBD', 'RP', 'IN', 'DT', 'JJ', 'NN', 'DT', 'NN', 'NN', 'IN', 'JJ', 'NN', 'CC', 'DT', 'NN', 'NN', 'IN', 'PRP$', 'NN', 'DT', 'PRP', 'VBD', 'VBD', 'DT', 'NN', 'IN', 'PRP', 'VBZ', 'JJ', 'NN', 'WRB', 'PDT', 'DT', 'JJ', 'NN', 'VBD', 'IN', 'PRP', 'VBZ', 'JJ', 'VB', 'PRP$', 'NNS', 'IN', 'DT', 'PRP$', 'NN', 'CC', 'NN', 'RB', 'VBD', ' ...

# %%
print(len(corpusfin))
# Out:
# 40

# %%
def biwordindex(t,corpus_words): 
    bind=[]
    for val in t:
        if (val =='NN' or val == 'NNS' or val == 'NNPS' or val == 'NNP'):
            #print("ifnoun")
            index= t.index(val)
            temp= corpus_words[index]
            #bind.append(temp)
            val2= t[index+1]
            term2=corpus_words[index+1]
            if(val2 =='NN' or val2 == 'NNS' or val2 == 'NNPS' or val2 == 'NNP'):
                temp= temp+" "+term2
                bind.append(temp)
                continue
            elif (val2=='DT' or val2=='IN'):
                temp= temp+" "+term2
                val3=t[index+2]
                term3=corpus_words[index+2]
                if(val3 =='NN' or val3 == 'NNS' or val3 == 'NNPS' or val3 == 'NNP'):
                    temp= temp+" "+term3   
                    bind.append(temp)
                    continue
                else:    
                    while(val3=='DT' or val3=='IN'):
                        term4=corpus_words[index+2]
                        nextval=t[index+2]
                        temp= temp+" "+term3
                        index +=1
                        if(nextval =='NN' or nextval == 'NNS' or nextval == 'NNPS' or nextval == 'NNP'):
                            temp= temp+" "+term4
                            bind.append(temp)
                            break
    return bind

# %%
bind = biwordindex(tip,corpus_words[10])
print(bind)
# Out:
# ['up as', 'as usual', 'as usual', 'as usual', 'up as', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'up as', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'up as', 'up as', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'up as', 'as usual', 'as usual', 'as usual', 'up as', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'up as', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'up as', 'up as', 'up as', 'up as', 'up as', 'up as', 'up as', 'as usual', 'as usual', 'up as', 'up as', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'as usual', 'up as', 'as usual']

# %%
bindex=[]
for corpus_word in corpus_words:
    t= biwords(corpus_word)
    bind = biwordindex(t,corpus_word)
    bindex.append(bind)
bindexfin=[]   
for bini in bindex:
    binif= list(set(bini))
    bindexfin.append(binif)

# %%
print(bindexfin)
# Out:
# [['Boy Who'], ['towards Uncle', 'Uncle Vernon'], ['escape of the the the boa', 'Letters from No'], ['Mr H', 'arms a lion'], ['sound of Dudley'], ['Uncle Vernon'], ['boat Icy', 'Uncle Vernon'], [], ['letter Dumbledore'], ['McKinnons the Bones', 'Ah Harry'], ['messin things'], ['Harry Mr', 'people in cloaks'], [], ['messin things'], ['towards Harry'], ['Hagrid A'], ['anyone s'], ['Don t', 'people from Muggle'], ['man Yes'], ['afternoon sun'], [], ['trolley round'], ['Mrs Dursley', 'sister No'], ['Harry Everywhere'], ['money for sweets', 'sweets with the the Dursleys'], ['didn t', 'Goodness didn', 'Scabbers the rat'], ['firs years', 'door swung'], ['Great Hall', 'heavens Harry'], ['thing Harry'], ['Weasley twins'], ['Gryffindors as the the Potions', 'Snape like Flitwick', 'Potions lessons'], ['room inside Hams'], ['barn owl'], ['dear Professor', 'Potters The rumour', 'My dear'], ['sight of Malfoy'], [], [], [], ['news Vernon', 'Bad news'], ['Dudley s']]

# %%
query= input("Enter the phrase to be searched:")
print("Your query is:", query)
# Out:
# Enter the phrase to be searched:afternoon sun
# Your query is: afternoon sun

# %%
flag= False
for ele in bindexfin:
    for i in ele:
        if i==query:
            print("Your phrase is in document number", bindexfin.index(ele))
            flag= True
            
if(flag==False):
    print("No match found")
# Out:
# Your phrase is in document number 19
